# %%
import torch, torchvision
from mobilenetv3 import MobileNetV3_forFPN, MobileNetV3, load_pretrained_fpn
from tests import test_loaded_weights, compare_output
# %load_ext autoreload
# %autoreload 2
torch.backends.cudnn.deterministic = True
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
mn3_fpn = MobileNetV3_forFPN()
mn3_fpn = load_pretrained_fpn(mn3_fpn,\
                              '/home/davidyuk/Projects/backbones/pytorch-mobilenet-v3/mobilenetv3_small_67.4.pth.tar')
# tuple(mn3_fpn.parameters())

# %%
test_loaded_weights()
# Out:
# test passed

# %%
def compare_output(model1, model2, tensor=torch.rand(1, 3, 64, 64), mode_train=True):
    
    if mode_train:
        model1.train(); model2.train()
    else:
        model1.eval(); model2.eval()
    with torch.no_grad():
        output1 = model1.forward(tensor)
        output2 = model2.forward(tensor)
    return output1, output2
output1, output2 = compare_output(mn3_fpn, mn3, mode_train=False)
print ((output2 == output1).all())
# Out:
# tensor(1, dtype=torch.uint8)

# %%
mn3_fpn.train()
mn3.train()
image = torch.rand(1, 3, 224, 224)
with torch.no_grad():
    output = mn3_fpn.forward(image)
    output1 = mn3.forward(image)
print ((output == output1).all())
# Out:
# tensor(1, dtype=torch.uint8)

# %%
mn3_fpn.eval()
mn3.eval()
image = torch.rand(1, 3, 224, 224)
with torch.no_grad():
    output = mn3_fpn.forward(image)
    output1 = mn3.forward(image)
print ((output == output1).all())
# Out:
# tensor(0, dtype=torch.uint8)

# %%
output1
# Out:
# tensor([[[[ 9.6878e-01,  1.0593e+00],
#           [ 1.7130e+00,  1.4174e+00]],
#
#          [[-5.5329e-01, -1.9280e-01],
#           [-3.8287e-01, -2.4750e-01]],
#
#          [[-1.0789e+00, -9.9800e-01],
#           [-1.1155e+00, -1.1900e+00]],
#
#          [[-6.4583e-01, -1.6241e-01],
#           [-4.0540e-01,  1.8898e-01]],
#
#          [[-1.9202e-01, -3.1282e-01],
#           [-5.6368e-02, -2.1342e-02]],
#
#          [[-8.7464e-02, -4.9753e-02],
#           [-5.0441e-02, -8.2843e-02]],
#
#          [[ 5.4918e-01,  9.9178e-01],
#           [-3.1458e-02,  5.0229e-01]],
#
#          [[-5.7466e-01, -7.3428e-02],
#           [ 3.2307e-01,  5.6378e-01]],
#
#          [[ 4.0531e-01,  6.7936e-02],
#           [ 1.6493e-01, -3.4961e-02]],
#
#          [[ 5.0198e-01,  4.6638e-01],
#           [ 6.6954e-01,  8.5917e-01]],
#
#          [[ 8.2104e-01,  5.4087e-01],
#           [ 4.8262e-01,  2.4466e-02]],
#
#          [[ 9.8456e-01,  6.7637e-01],
#           [ 8.7218e-01,  7.9163e-01]],
#
# ...

# %%
output2
# Out:
# tensor([[[[ 8.2469e-01,  8.9292e-01],
#           [ 1.6041e+00,  1.3369e+00]],
#
#          [[-6.2671e-01, -1.8699e-01],
#           [-5.4763e-01, -4.4949e-01]],
#
#          [[-1.1521e+00, -1.0304e+00],
#           [-1.2658e+00, -1.2877e+00]],
#
#          [[-4.1331e-01,  1.4272e-01],
#           [-2.6828e-01,  3.8579e-01]],
#
#          [[-1.7110e-01, -4.6798e-01],
#           [-1.1886e-01, -1.8892e-01]],
#
#          [[-1.8615e-01, -1.7686e-01],
#           [ 1.2411e-02,  4.1023e-03]],
#
#          [[ 5.1663e-01,  7.1785e-01],
#           [ 5.9332e-02,  4.9109e-01]],
#
#          [[-5.6637e-01, -1.6524e-01],
#           [ 1.4870e-01,  3.9193e-01]],
#
#          [[ 3.8926e-01,  2.3813e-02],
#           [ 2.4604e-01,  3.9255e-02]],
#
#          [[ 2.2964e-01,  2.4935e-01],
#           [ 2.8104e-01,  5.3301e-01]],
#
#          [[ 9.7548e-01,  6.1267e-01],
#           [ 5.4615e-01,  1.4912e-01]],
#
#          [[ 1.2215e+00,  5.5311e-01],
#           [ 1.3156e+00,  9.1373e-01]],
#
# ...

# %%
path = '/home/davidyuk/Projects/backbones/pytorch-mobilenet-v3/mobilenetv3_small_67.4.pth.tar'
mn3_fpn = MobileNetV3_forFPN()
mn3_fpn = load_pretrained_fpn(mn3_fpn, path)

mobNetv3 = MobileNetV3(mode='small')
state_dict = torch.load(path, map_location='cpu')
mobNetv3.load_state_dict(state_dict)
mobNetv3 = mobNetv3.features[:12]
# for param, base_param in zip(mn3_fpn.parameters(), mobNetv3.parameters()):
#     print((param == base_param).all())
# print(len(tuple(mn3_fpn.parameters())),len(tuple(mobNetv3.parameters())))

mobNetv3.eval()
mn3_fpn.eval()

image = torch.ones((1, 3, 32, 32), requires_grad=False)
image1 = torch.ones((1, 3, 32, 32), requires_grad=False)
with torch.no_grad():
    output = mn3_fpn.forward(image)
    output1 = mobNetv3.forward(image1)

print ((output == output1).all())
# if (output == output1).all():
#     print('test passed')
# else:
#     print('test failed')

# %%
list(mn3_fpn.parameters())

# %%
torch.hub.list('rwightman/gen-efficientnet-pytorch')

# %%
model = torch.hub.load('rwightman/gen-efficientnet-pytorch', 'mobilenetv3_100', pretrained=True)

# %%
model = torch.hub.load('rwightman/gen-efficientnet-pytorch', 'mobilenetv3_100', pretrained=True)
model.classifier = torch.nn.Linear(1280,2)
model
